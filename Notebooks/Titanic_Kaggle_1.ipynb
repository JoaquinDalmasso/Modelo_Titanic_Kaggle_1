# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_train.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df_train.shape
# Out:
# (891, 12)

# %%
print(pd.isnull(df_train).sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Visualizacion de los datos

# %%
print('Cantidad total de mujeres a bordo: ',df_train['Sex'].value_counts()['female'])
print('Cantidad total de hombres a bordo: ',df_train['Sex'].value_counts()['male'])
print('Porcentaje de mujeres que sobrevivieron: ', df_train['Survived'][df_train['Sex']=='female'].value_counts(normalize = True)[1]*100)
print('Porcentaje de hombres que sobrevivieron: ', df_train['Survived'][df_train['Sex']=='male'].value_counts(normalize = True)[1]*100)
print('Esto quiere decir que sobrevivieron ',df_train['Sex'].value_counts()['female']*df_train['Survived'][df_train['Sex']=='female'].value_counts(normalize = True)[1],'Mujeres y ',df_train['Sex'].value_counts()['male']*df_train['Survived'][df_train['Sex']=='male'].value_counts(normalize = True)[1],'Hombres')
sns.barplot(data=df_train, x='Sex', y='Survived')
plt.show()
# Out:
# Cantidad total de mujeres a bordo:  314
# Cantidad total de hombres a bordo:  577
# Porcentaje de mujeres que sobrevivieron:  74.20382165605095
# Porcentaje de hombres que sobrevivieron:  18.890814558058924
# Esto quiere decir que sobrevivieron  232.99999999999997 Mujeres y  109.0 Hombres

# %%
print('Porcentaje de personas de Pclass = 1 que sobrevivieron: ', df_train['Survived'][df_train['Pclass']==1].value_counts(normalize = True)[1]*100)
print('Porcentaje de personas de Pclass = 2 que sobrevivieron: ', df_train['Survived'][df_train['Pclass']==2].value_counts(normalize = True)[1]*100)
print('Porcentaje de personas de Pclass = 3 que sobrevivieron: ', df_train['Survived'][df_train['Pclass']==3].value_counts(normalize = True)[1]*100)
sns.barplot(data=df_train, x='Pclass', y='Survived')
plt.show()
# Out:
# Porcentaje de personas de Pclass = 1 que sobrevivieron:  62.96296296296296
# Porcentaje de personas de Pclass = 2 que sobrevivieron:  47.28260869565217
# Porcentaje de personas de Pclass = 3 que sobrevivieron:  24.236252545824847

# %%
print('Las personas con 0 hermanos a bordo tienen: ', df_train['Survived'][df_train['SibSp']==0].value_counts(normalize = True)[1]*100,'% probabilidades de sobrevivir')
print('Las personas con 1 hermano a bordo tienen: ', df_train['Survived'][df_train['SibSp']==1].value_counts(normalize = True)[1]*100,'% probabilidades de sobrevivir')
print('Las personas con 2 hermanos a bordo tienen: ', df_train['Survived'][df_train['SibSp']==2].value_counts(normalize = True)[1]*100,'% probabilidades de sobrevivir')
print('Las personas con 3 hermanos a bordo tienen: ', df_train['Survived'][df_train['SibSp']==3].value_counts(normalize = True)[1]*100,'% probabilidades de sobrevivir')
print('Las personas con 4 hermanos a bordo tienen: ', df_train['Survived'][df_train['SibSp']==4].value_counts(normalize = True)[1]*100,'% probabilidades de sobrevivir')
sns.barplot(data=df_train, x='SibSp', y='Survived')
plt.show()
# Out:
# Las personas con 0 hermanos a bordo tienen:  34.53947368421053 % probabilidades de sobrevivir
# Las personas con 1 hermano a bordo tienen:  53.588516746411486 % probabilidades de sobrevivir
# Las personas con 2 hermanos a bordo tienen:  46.42857142857143 % probabilidades de sobrevivir
# Las personas con 3 hermanos a bordo tienen:  25.0 % probabilidades de sobrevivir
# Las personas con 4 hermanos a bordo tienen:  16.666666666666664 % probabilidades de sobrevivir

# %%
sns.barplot(data=df_train, x='Parch', y='Survived')
plt.show()

# %%
df_train["Age"] = df_train["Age"].fillna(-0.5)
df_test["Age"] = df_test["Age"].fillna(-0.5)
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
df_train['AgeGroup'] = pd.cut(df_train["Age"], bins, labels = labels)
df_test['AgeGroup'] = pd.cut(df_test["Age"], bins, labels = labels)
sns.barplot(data=df_train, x="AgeGroup", y="Survived")
plt.show()

# %%
df_train["CabinBool"] = (df_train["Cabin"].notnull().astype('int'))
df_test["CabinBool"] = (df_test["Cabin"].notnull().astype('int'))
print("Porcentaje de personas en Cabina que sobrevivieron", df_train["Survived"][df_train["CabinBool"] == 1].value_counts(normalize = True)[1]*100)
print("Porcentaje de personas sin Cabina que sobrevivieron", df_train["Survived"][df_train["CabinBool"] == 0].value_counts(normalize = True)[1]*100)
sns.barplot(data=df_train, x="CabinBool", y="Survived")
plt.show()
# Out:
# Porcentaje de personas en Cabina que sobrevivieron 66.66666666666666
# Porcentaje de personas sin Cabina que sobrevivieron 29.985443959243085

# %% [markdown]
# # Limpieza de datos

# %%
df_train = df_train.drop(['Cabin'], axis=1)
df_test = df_test.drop(['Cabin'], axis=1)

# %%
df_train = df_train.drop(['Ticket'], axis=1)
df_test = df_test.drop(['Ticket'], axis=1)

# %%
print("Cantidad de personas que embarcaron en Southampton (S):")
southampton = df_train[df_train["Embarked"] == "S"].shape[0]
print(southampton)

print("Cantidad de personas que embarcaron en Cherbourg (C):")
cherbourg = df_train[df_train["Embarked"] == "C"].shape[0]
print(cherbourg)

print("Cantidad de personas que embarcaron en Queenstown (Q):")
queenstown = df_train[df_train["Embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Cantidad de personas que embarcaron en Southampton (S):
# 644
# Cantidad de personas que embarcaron en Cherbourg (C):
# 168
# Cantidad de personas que embarcaron en Queenstown (Q):
# 77

# %%
df_train = df_train.fillna({"Embarked": "S"})

# %%
#Combinamos los dos datasets
combine = [df_train, df_test]

#Extraccion de un titulo para cada Name en los datasets
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(df_train['Title'], df_train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Capt', 'Col',
    'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

df_train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.285714
# 5   Royal  1.000000

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked     AgeGroup  CabinBool  Title
# 0      0   7.2500        S      Student          0      1
# 1      0  71.2833        C        Adult          1      3
# 2      0   7.9250        S  Young Adult          0      2
# 3      0  53.1000        S  Young Adult          1      3
# ...

# %%
mr_age = df_train[df_train["Title"] == 1]["AgeGroup"].mode() #Young Adult
miss_age = df_train[df_train["Title"] == 2]["AgeGroup"].mode() #Student
mrs_age = df_train[df_train["Title"] == 3]["AgeGroup"].mode() #Adult
master_age = df_train[df_train["Title"] == 4]["AgeGroup"].mode() #Baby
royal_age = df_train[df_train["Title"] == 5]["AgeGroup"].mode() #Adult
rare_age = df_train[df_train["Title"] == 6]["AgeGroup"].mode() #Adult

age_title_mapping = {1: "Young Adult", 2: "Student", 3: "Adult", 4: "Baby", 5: "Adult", 6: "Adult"}

for x in range(len(df_train["AgeGroup"])):
    if df_train["AgeGroup"][x] == "Unknown":
        df_train["AgeGroup"][x] = age_title_mapping[df_train["Title"][x]]

for x in range(len(df_test["AgeGroup"])):
    if df_test["AgeGroup"][x] == "Unknown":
        df_test["AgeGroup"][x] = age_title_mapping[df_test["Title"][x]]

# %%
age_mapping = {'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}
df_train['AgeGroup'] = df_train['AgeGroup'].map(age_mapping)
df_test['AgeGroup'] = df_test['AgeGroup'].map(age_mapping)

# %%
df_train = df_train.drop(['Age'], axis = 1)
df_test = df_test.drop(['Age'], axis = 1)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#       Fare Embarked  AgeGroup  CabinBool  Title
# 0   7.2500        S       4.0          0      1
# 1  71.2833        C       6.0          1      3
# 2   7.9250        S       5.0          0      2
# 3  53.1000        S       5.0          1      3
# 4   8.0500        S       5.0          0      1

# %%
df_train = df_train.drop(['Name'], axis = 1)
df_test = df_test.drop(['Name'], axis = 1)

# %%
sex_mapping = {"male": 0, "female": 1}
df_train['Sex'] = df_train['Sex'].map(sex_mapping)
df_test['Sex'] = df_test['Sex'].map(sex_mapping)

df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  \
# 0            1         0       3    0      1      0   7.2500        S
# 1            2         1       1    1      1      0  71.2833        C
# 2            3         1       3    1      0      0   7.9250        S
# 3            4         1       1    1      1      0  53.1000        S
# 4            5         0       3    0      0      0   8.0500        S
#
#    AgeGroup  CabinBool  Title
# 0       4.0          0      1
# 1       6.0          1      3
# 2       5.0          0      2
# 3       5.0          1      3
# 4       5.0          0      1

# %%
embarked_mapping = {"S": 1, "C": 2, "Q": 3}
df_train['Embarked'] = df_train['Embarked'].map(embarked_mapping)
df_test['Embarked'] = df_test['Embarked'].map(embarked_mapping)

df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    0      1      0   7.2500         1
# 1            2         1       1    1      1      0  71.2833         2
# 2            3         1       3    1      0      0   7.9250         1
# 3            4         1       1    1      1      0  53.1000         1
# 4            5         0       3    0      0      0   8.0500         1
#
#    AgeGroup  CabinBool  Title
# 0       4.0          0      1
# 1       6.0          1      3
# 2       5.0          0      2
# 3       5.0          1      3
# 4       5.0          0      1

# %%
for x in range(len(df_test["Fare"])):
    if pd.isnull(df_test["Fare"][x]):
        pclass = df_test["Pclass"][x] #Pclass = 3
        df_test["Fare"][x] = round(df_train[df_train["Pclass"] == pclass]["Fare"].mean(), 4)
# Out:
# <ipython-input-32-d90f03152151>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test["Fare"][x] = round(df_train[df_train["Pclass"] == pclass]["Fare"].mean(), 4)

# %%
df_train['FareBand'] = pd.qcut(df_train['Fare'], 4, labels = [1, 2, 3, 4])
df_test['FareBand'] = pd.qcut(df_test['Fare'], 4, labels = [1, 2, 3, 4])

#drop Fare values
df_train = df_train.drop(['Fare'], axis = 1)
df_test = df_test.drop(['Fare'], axis = 1)

# %%
print(pd.isnull(df_train).sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# SibSp          0
# Parch          0
# Embarked       0
# AgeGroup       0
# CabinBool      0
# Title          0
# FareBand       0
# dtype: int64

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  \
# 0            1         0       3    0      1      0         1       4.0
# 1            2         1       1    1      1      0         2       6.0
# 2            3         1       3    1      0      0         1       5.0
# 3            4         1       1    1      1      0         1       5.0
# 4            5         0       3    0      0      0         1       5.0
#
#    CabinBool  Title FareBand
# 0          0      1        1
# 1          1      3        4
# 2          0      2        2
# 3          1      3        4
# 4          0      1        2

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  CabinBool  \
# 0          892       3    0      0      0         3       5.0          0
# 1          893       3    1      1      0         1       6.0          0
# 2          894       2    0      0      0         3       7.0          0
# 3          895       3    0      0      0         1       5.0          0
# 4          896       3    1      1      1         1       4.0          0
#
#    Title FareBand
# 0      1        1
# 1      3        1
# 2      1        2
# 3      1        2
# 4      3        2

# %% [markdown]
# # Verificando el mejor modelo

# %%
from sklearn.model_selection import train_test_split

predictors = df_train.drop(['Survived', 'PassengerId'], axis=1)
target = df_train["Survived"]
X_train, X_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.22, random_state = 0)

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
y_pred = gaussian.predict(X_val)
acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 78.68

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_val)
acc_logreg = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_logreg)
# Out:
# 79.7

# %%
# Support Vector Machines
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)
y_pred = svc.predict(X_val)
acc_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_svc)
# Out:
# 82.74

# %%
# Linear SVC
from sklearn.svm import LinearSVC

linear_svc = LinearSVC()
linear_svc.fit(X_train, y_train)
y_pred = linear_svc.predict(X_val)
acc_linear_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_linear_svc)
# Out:
# 78.68
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
# Perceptron
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(X_train, y_train)
y_pred = perceptron.predict(X_val)
acc_perceptron = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_perceptron)
# Out:
# 78.68

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(X_train, y_train)
y_pred = decisiontree.predict(X_val)
acc_decisiontree = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_decisiontree)
# Out:
# 80.2

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(X_train, y_train)
y_pred = randomforest.predict(X_val)
acc_randomforest = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_randomforest)
# Out:
# 84.77

# %%
# KNN or k-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_val)
acc_knn = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_knn)
# Out:
# 82.23

# %%
# Stochastic Gradient Descent
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(X_train, y_train)
y_pred = sgd.predict(X_val)
acc_sgd = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_sgd)
# Out:
# 79.19

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(X_train, y_train)
y_pred = gbk.predict(X_val)
acc_gbk = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gbk)
# Out:
# 84.77

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression',
              'Random Forest', 'Naive Bayes', 'Perceptron', 'Linear SVC',
              'Decision Tree', 'Stochastic Gradient Descent', 'Gradient Boosting Classifier'],
    'Score': [acc_svc, acc_knn, acc_logreg,
              acc_randomforest, acc_gaussian, acc_perceptron,acc_linear_svc, acc_decisiontree,
              acc_sgd, acc_gbk]})
models.sort_values(by='Score', ascending=False)
# Out:
#                           Model  Score
# 3                 Random Forest  84.77
# 9  Gradient Boosting Classifier  84.77
# 0       Support Vector Machines  82.74
# 1                           KNN  82.23
# 7                 Decision Tree  80.20
# 2           Logistic Regression  79.70
# 8   Stochastic Gradient Descent  79.19
# 4                   Naive Bayes  78.68
# 5                    Perceptron  78.68
# 6                    Linear SVC  78.68
